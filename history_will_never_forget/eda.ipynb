# %%
import pandas as pd
import pandas as pd

# %%
df = pd.read_csv('data/multipleChoiceResponses.csv')
# Out:
# /home/ptyshevskyi/envs/loc_env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(3).T
# Out:
#                                                                                      0  \
# Time from Start to Finish (seconds)                              Duration (in seconds)
# Q1                                              What is your gender? - Selected Choice
# Q1_OTHER_TEXT                        What is your gender? - Prefer to self-describe...
# Q2                                                         What is your age (# years)?
# Q3                                           In which country do you currently reside?
# ...                                                                                ...
# Q50_Part_5                           What barriers prevent you from making your wor...
# Q50_Part_6                           What barriers prevent you from making your wor...
# Q50_Part_7                           What barriers prevent you from making your wor...
# Q50_Part_8                           What barriers prevent you from making your wor...
# ...

# %%
c = df['Q9'].astype('category')

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
c.cat.categories
# Out:
# Index(['0-10,000', '10-20,000', '100-125,000', '125-150,000', '150-200,000',
#        '20-30,000', '200-250,000', '250-300,000', '30-40,000', '300-400,000',
#        '40-50,000', '400-500,000', '50-60,000', '500,000+', '60-70,000',
#        '70-80,000', '80-90,000', '90-100,000',
#        'I do not wish to disclose my approximate yearly compensation',
#        'What is your current yearly compensation (approximate $USD)?'],
#       dtype='object')

# %%
'I do not wish to disclose my approximate yearly compensation'.sum()
# Out:
# 4756

# %%
c[(~pd.isna(c)) & (~)]
# Out:
# 0        What is your current yearly compensation (appr...
# 2                                                10-20,000
# 3                                                 0-10,000
# 5                                                 0-10,000
# 6        I do not wish to disclose my approximate yearl...
#                                ...
# 23848    I do not wish to disclose my approximate yearl...
# 23850    I do not wish to disclose my approximate yearl...
# 23854                                            10-20,000
# 23855                                          250-300,000
# 23857                                            10-20,000
# Name: Q9, Length: 20186, dtype: category
# Categories (20, object): [0-10,000, 10-20,000, 100-125,000, 125-150,000, ..., 80-90,000, 90-100,000, I do not wish to disclose my approximate yearl..., What is your current yearly compensation (appr...]

# %%
c[c == np.nan]
# Out:
# Series([], Name: Q9, dtype: category
# Categories (20, object): [0-10,000, 10-20,000, 100-125,000, 125-150,000, ..., 80-90,000, 90-100,000, I do not wish to disclose my approximate yearl..., What is your current yearly compensation (appr...])

# %%
plt.figure(figsize=(16, 8))
print(c.value_counts(dropna=False))
c.value_counts(dropna=False).plot(kind='bar');
# Out:
# I do not wish to disclose my approximate yearly compensation    4756
# 0-10,000                                                        4398
# NaN                                                             3674
# 10-20,000                                                       1937
# 20-30,000                                                       1395
# 30-40,000                                                       1119
# 40-50,000                                                        965
# 50-60,000                                                        919
# 100-125,000                                                      843
# 60-70,000                                                        729
# 70-80,000                                                        677
# 90-100,000                                                       566
# 125-150,000                                                      533
# 80-90,000                                                        506
# ...

# %%
print(df['Q3'].astype('category').value_counts()[:50])
plt.figure(figsize=(13, 8))
df['Q3'].astype('category').value_counts().plot(kind='bar')
# Out:
# United States of America                                4716
# India                                                   4417
# China                                                   1644
# Other                                                   1036
# Russia                                                   879
# Brazil                                                   736
# Germany                                                  734
# United Kingdom of Great Britain and Northern Ireland     702
# Canada                                                   604
# France                                                   604
# Japan                                                    597
# Spain                                                    485
# I do not wish to disclose my location                    394
# Italy                                                    355
# Australia                                                330
# ...
